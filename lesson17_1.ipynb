# %%
import pandas as pd
data = {"字串":["台北", "台中"],
        "整數":[1000, 3000],
        "浮點數":[3.258, 7.396]}

df = pd.DataFrame(data)
display(df)
# Out:
#    字串    整數    浮點數
# 0  台北  1000  3.258
# 1  台中  3000  7.396

# %%
#視覺美化資料表
#pip install jinja2
df.style\
.format(precision=2,thousands=",",decimal=".")\
.relabel_index(["列1","列2"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_72a32">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72a32_level0_col0" class="col_heading level0 col0" >字串</th>
#       <th id="T_72a32_level0_col1" class="col_heading level0 col1" >整數</th>
#       <th id="T_72a32_level0_col2" class="col_heading level0 col2" >浮點數</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72a32_level0_row0" class="row_heading level0 row0" >列1</th>
#       <td id="T_72a32_row0_col0" class="data row0 col0" >台北</td>
#       <td id="T_72a32_row0_col1" class="data row0 col1" >1,000</td>
#       <td id="T_72a32_row0_col2" class="data row0 col2" >3.26</td>
#     </tr>
#     <tr>
#       <th id="T_72a32_level0_row1" class="row_heading level0 row1" >列2</th>
#       <td id="T_72a32_row1_col0" class="data row1 col0" >台中</td>
#       <td id="T_72a32_row1_col1" class="data row1 col1" >3,000</td>
#       <td id="T_72a32_row1_col2" class="data row1 col2" >7.40</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
data = np.random.rand(10,2) * 5
df = pd.DataFrame(data,
                  index = pd.date_range(start="2023-09-01",periods=10),
                  columns=["台北","台中"]
                  )
df
# Out:
#                   台北        台中
# 2023-09-01  0.516505  4.222378
# 2023-09-02  2.070355  0.129063
# 2023-09-03  2.739155  0.241190
# 2023-09-04  0.794204  0.689648
# 2023-09-05  0.186178  2.869087
# 2023-09-06  3.271120  4.049852
# 2023-09-07  1.329035  0.935875
# 2023-09-08  3.274111  1.336693
# 2023-09-09  4.464060  0.077328
# 2023-09-10  0.244848  3.756595

# %%
#視覺美化資料表
def feel_condition(v):
    if v < 1.75:
        return "溫暖"
    elif v < 2.75:
        return "潮溼"
    else:
        return "日照"
    
df.style\
.format(feel_condition)\
.set_caption("體感溫度")\
.background_gradient(cmap="PuBuGn",vmin=1,vmax=5,axis=None)
# Out:
# <style type="text/css">
# #T_3b1f1_row0_col0, #T_3b1f1_row1_col1, #T_3b1f1_row2_col1, #T_3b1f1_row3_col0, #T_3b1f1_row3_col1, #T_3b1f1_row4_col0, #T_3b1f1_row6_col1, #T_3b1f1_row8_col1, #T_3b1f1_row9_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3b1f1_row0_col1 {
#   background-color: #027773;
#   color: #f1f1f1;
# }
# #T_3b1f1_row1_col0 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_3b1f1_row2_col0 {
#   background-color: #88b3d5;
#   color: #000000;
# }
# #T_3b1f1_row4_col1 {
#   background-color: #78aed2;
#   color: #f1f1f1;
# }
# #T_3b1f1_row5_col0, #T_3b1f1_row7_col0 {
#   background-color: #4c9bc7;
#   color: #f1f1f1;
# }
# #T_3b1f1_row5_col1 {
#   background-color: #027f84;
#   color: #f1f1f1;
# }
# #T_3b1f1_row6_col0, #T_3b1f1_row7_col1 {
#   background-color: #f2e9f4;
#   color: #000000;
# }
# #T_3b1f1_row8_col0 {
#   background-color: #016d5c;
#   color: #f1f1f1;
# }
# #T_3b1f1_row9_col1 {
#   background-color: #1b88a4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3b1f1">
#   <caption>體感溫度</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b1f1_level0_col0" class="col_heading level0 col0" >台北</th>
#       <th id="T_3b1f1_level0_col1" class="col_heading level0 col1" >台中</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b1f1_level0_row0" class="row_heading level0 row0" >2023-09-01 00:00:00</th>
#       <td id="T_3b1f1_row0_col0" class="data row0 col0" >溫暖</td>
#       <td id="T_3b1f1_row0_col1" class="data row0 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row1" class="row_heading level0 row1" >2023-09-02 00:00:00</th>
#       <td id="T_3b1f1_row1_col0" class="data row1 col0" >潮溼</td>
#       <td id="T_3b1f1_row1_col1" class="data row1 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row2" class="row_heading level0 row2" >2023-09-03 00:00:00</th>
#       <td id="T_3b1f1_row2_col0" class="data row2 col0" >潮溼</td>
#       <td id="T_3b1f1_row2_col1" class="data row2 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row3" class="row_heading level0 row3" >2023-09-04 00:00:00</th>
#       <td id="T_3b1f1_row3_col0" class="data row3 col0" >溫暖</td>
#       <td id="T_3b1f1_row3_col1" class="data row3 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row4" class="row_heading level0 row4" >2023-09-05 00:00:00</th>
#       <td id="T_3b1f1_row4_col0" class="data row4 col0" >溫暖</td>
#       <td id="T_3b1f1_row4_col1" class="data row4 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row5" class="row_heading level0 row5" >2023-09-06 00:00:00</th>
#       <td id="T_3b1f1_row5_col0" class="data row5 col0" >日照</td>
#       <td id="T_3b1f1_row5_col1" class="data row5 col1" >日照</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row6" class="row_heading level0 row6" >2023-09-07 00:00:00</th>
#       <td id="T_3b1f1_row6_col0" class="data row6 col0" >溫暖</td>
#       <td id="T_3b1f1_row6_col1" class="data row6 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row7" class="row_heading level0 row7" >2023-09-08 00:00:00</th>
#       <td id="T_3b1f1_row7_col0" class="data row7 col0" >日照</td>
#       <td id="T_3b1f1_row7_col1" class="data row7 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row8" class="row_heading level0 row8" >2023-09-09 00:00:00</th>
#       <td id="T_3b1f1_row8_col0" class="data row8 col0" >日照</td>
#       <td id="T_3b1f1_row8_col1" class="data row8 col1" >溫暖</td>
#     </tr>
#     <tr>
#       <th id="T_3b1f1_level0_row9" class="row_heading level0 row9" >2023-09-10 00:00:00</th>
#       <td id="T_3b1f1_row9_col0" class="data row9 col0" >溫暖</td>
#       <td id="T_3b1f1_row9_col1" class="data row9 col1" >日照</td>
#     </tr>
#   </tbody>
# </table>

# %%
#隱藏資料
df = pd.DataFrame(np.random.randn(5,5))
df.style\
.hide(subset=[0, 2, 4],axis=0)\
.hide(subset=[1,3],axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_918dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_918dd_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_918dd_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_918dd_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_918dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_918dd_row1_col0" class="data row1 col0" >-1.009200</td>
#       <td id="T_918dd_row1_col2" class="data row1 col2" >-0.006120</td>
#       <td id="T_918dd_row1_col4" class="data row1 col4" >-0.906016</td>
#     </tr>
#     <tr>
#       <th id="T_918dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_918dd_row3_col0" class="data row3 col0" >-0.538759</td>
#       <td id="T_918dd_row3_col2" class="data row3 col2" >-0.182065</td>
#       <td id="T_918dd_row3_col4" class="data row3 col4" >0.292762</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(np.random.randn(10,4),
             columns=["A", "B", "C", "D"])
display(df)

def style_negative(v, props=''):
    return props if v < 0 else None

df.style\
.map(style_negative,props='color:red;')
# Out:
#           A         B         C         D
# 0  0.859932 -2.765676 -0.137287 -1.327523
# 1  2.915479  0.354934  1.623555  0.909532
# 2 -0.204852  0.133490  0.886770 -1.112234
# 3 -1.278230  0.194214  1.179965 -0.657985
# 4  1.175630  0.354274  0.623878  0.514965
# 5  1.628772 -0.742921 -0.479182 -0.631664
# 6 -0.036389  1.943193  0.327155  0.234431
# 7 -1.730252 -0.167973 -0.315001 -0.626310
# 8  0.485029 -1.476843  0.253748 -1.786093
# 9  0.925344  1.737589 -1.446099  0.276607
# <style type="text/css">
# #T_efca0_row0_col1, #T_efca0_row0_col2, #T_efca0_row0_col3, #T_efca0_row2_col0, #T_efca0_row2_col3, #T_efca0_row3_col0, #T_efca0_row3_col3, #T_efca0_row5_col1, #T_efca0_row5_col2, #T_efca0_row5_col3, #T_efca0_row6_col0, #T_efca0_row7_col0, #T_efca0_row7_col1, #T_efca0_row7_col2, #T_efca0_row7_col3, #T_efca0_row8_col1, #T_efca0_row8_col3, #T_efca0_row9_col2 {
#   color: red;
# }
# </style>
# <table id="T_efca0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efca0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_efca0_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_efca0_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_efca0_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efca0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efca0_row0_col0" class="data row0 col0" >0.859932</td>
#       <td id="T_efca0_row0_col1" class="data row0 col1" >-2.765676</td>
#       <td id="T_efca0_row0_col2" class="data row0 col2" >-0.137287</td>
#       <td id="T_efca0_row0_col3" class="data row0 col3" >-1.327523</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efca0_row1_col0" class="data row1 col0" >2.915479</td>
#       <td id="T_efca0_row1_col1" class="data row1 col1" >0.354934</td>
#       <td id="T_efca0_row1_col2" class="data row1 col2" >1.623555</td>
#       <td id="T_efca0_row1_col3" class="data row1 col3" >0.909532</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efca0_row2_col0" class="data row2 col0" >-0.204852</td>
#       <td id="T_efca0_row2_col1" class="data row2 col1" >0.133490</td>
#       <td id="T_efca0_row2_col2" class="data row2 col2" >0.886770</td>
#       <td id="T_efca0_row2_col3" class="data row2 col3" >-1.112234</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efca0_row3_col0" class="data row3 col0" >-1.278230</td>
#       <td id="T_efca0_row3_col1" class="data row3 col1" >0.194214</td>
#       <td id="T_efca0_row3_col2" class="data row3 col2" >1.179965</td>
#       <td id="T_efca0_row3_col3" class="data row3 col3" >-0.657985</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efca0_row4_col0" class="data row4 col0" >1.175630</td>
#       <td id="T_efca0_row4_col1" class="data row4 col1" >0.354274</td>
#       <td id="T_efca0_row4_col2" class="data row4 col2" >0.623878</td>
#       <td id="T_efca0_row4_col3" class="data row4 col3" >0.514965</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_efca0_row5_col0" class="data row5 col0" >1.628772</td>
#       <td id="T_efca0_row5_col1" class="data row5 col1" >-0.742921</td>
#       <td id="T_efca0_row5_col2" class="data row5 col2" >-0.479182</td>
#       <td id="T_efca0_row5_col3" class="data row5 col3" >-0.631664</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_efca0_row6_col0" class="data row6 col0" >-0.036389</td>
#       <td id="T_efca0_row6_col1" class="data row6 col1" >1.943193</td>
#       <td id="T_efca0_row6_col2" class="data row6 col2" >0.327155</td>
#       <td id="T_efca0_row6_col3" class="data row6 col3" >0.234431</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_efca0_row7_col0" class="data row7 col0" >-1.730252</td>
#       <td id="T_efca0_row7_col1" class="data row7 col1" >-0.167973</td>
#       <td id="T_efca0_row7_col2" class="data row7 col2" >-0.315001</td>
#       <td id="T_efca0_row7_col3" class="data row7 col3" >-0.626310</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_efca0_row8_col0" class="data row8 col0" >0.485029</td>
#       <td id="T_efca0_row8_col1" class="data row8 col1" >-1.476843</td>
#       <td id="T_efca0_row8_col2" class="data row8 col2" >0.253748</td>
#       <td id="T_efca0_row8_col3" class="data row8 col3" >-1.786093</td>
#     </tr>
#     <tr>
#       <th id="T_efca0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_efca0_row9_col0" class="data row9 col0" >0.925344</td>
#       <td id="T_efca0_row9_col1" class="data row9 col1" >1.737589</td>
#       <td id="T_efca0_row9_col2" class="data row9 col2" >-1.446099</td>
#       <td id="T_efca0_row9_col3" class="data row9 col3" >0.276607</td>
#     </tr>
#   </tbody>
# </table>
